# %%
from __future__ import annotations

import operator
from pathlib import Path
from typing import TypedDict, List, Annotated, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=5,
        description="3–5 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(
        ...,
        description="Target word count for this section (120–450).",
    )
    section_type: Literal[
        "intro", "core", "examples", "checklist", "common_mistakes", "conclusion"
    ] = Field(
        ...,
        description="Use 'common_mistakes' exactly once in the plan.",
    )

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str = Field(..., description="Who this blog is for.")
    tone: str = Field(..., description="Writing tone (e.g., practical, crisp).")
    tasks: List[Task]

# %%
class State(TypedDict):
    topic: str
    plan: Plan
    sections: Annotated[List[str], operator.add]  # reducer concatenates worker outputs
    final: str

# %%
load_dotenv()
llm = ChatOpenAI(model="gpt-4.1-mini")

# %%
def orchestrator(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    plan = planner.invoke(
        [
            SystemMessage(
                content=(
                    "You are a senior technical writer and developer advocate. Your job is to produce a "
                    "highly actionable outline for a technical blog post.\n\n"
                    "Hard requirements:\n"
                    "- Create 5–7 sections (tasks) that fit a technical blog.\n"
                    "- Each section must include:\n"
                    "  1) goal (1 sentence: what the reader can do/understand after the section)\n"
                    "  2) 3–5 bullets that are concrete, specific, and non-overlapping\n"
                    "  3) target word count (120–450)\n"
                    "- Include EXACTLY ONE section with section_type='common_mistakes'.\n\n"
                    "Make it technical (not generic):\n"
                    "- Assume the reader is a developer; use correct terminology.\n"
                    "- Prefer design/engineering structure: problem → intuition → approach → implementation → "
                    "trade-offs → testing/observability → conclusion.\n"
                    "- Bullets must be actionable and testable (e.g., 'Show a minimal code snippet for X', "
                    "'Explain why Y fails under Z condition', 'Add a checklist for production readiness').\n"
                    "- Explicitly include at least ONE of the following somewhere in the plan (as bullets):\n"
                    "  * a minimal working example (MWE) or code sketch\n"
                    "  * edge cases / failure modes\n"
                    "  * performance/cost considerations\n"
                    "  * security/privacy considerations (if relevant)\n"
                    "  * debugging tips / observability (logs, metrics, traces)\n"
                    "- Avoid vague bullets like 'Explain X' or 'Discuss Y'. Every bullet should state what "
                    "to build/compare/measure/verify.\n\n"
                    "Ordering guidance:\n"
                    "- Start with a crisp intro and problem framing.\n"
                    "- Build core concepts before advanced details.\n"
                    "- Include one section for common mistakes and how to avoid them.\n"
                    "- End with a practical summary/checklist and next steps.\n\n"
                    "Output must strictly match the Plan schema."
                )
            ),
            HumanMessage(content=f"Topic: {state['topic']}"),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {"task": task, "topic": state["topic"], "plan": state["plan"]},
        )
        for task in state["plan"].tasks
    ]

# %%
def worker(payload: dict) -> dict:

    task = payload["task"]
    topic = payload["topic"]
    plan = payload["plan"]

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    section_md = llm.invoke(
        [
            SystemMessage(
    content=(
        "You are a senior technical writer and developer advocate. Write ONE section of a technical blog post in Markdown.\n\n"
        "Hard constraints:\n"
        "- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).\n"
        "- Stay close to the Target words (±15%).\n"
        "- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).\n\n"
        "Technical quality bar:\n"
        "- Be precise and implementation-oriented (developers should be able to apply it).\n"
        "- Prefer concrete details over abstractions: APIs, data structures, protocols, and exact terms.\n"
        "- When relevant, include at least one of:\n"
        "  * a small code snippet (minimal, correct, and idiomatic)\n"
        "  * a tiny example input/output\n"
        "  * a checklist of steps\n"
        "  * a diagram described in text (e.g., 'Flow: A -> B -> C')\n"
        "- Explain trade-offs briefly (performance, cost, complexity, reliability).\n"
        "- Call out edge cases / failure modes and what to do about them.\n"
        "- If you mention a best practice, add the 'why' in one sentence.\n\n"
        "Markdown style:\n"
        "- Start with a '## <Section Title>' heading.\n"
        "- Use short paragraphs, bullet lists where helpful, and code fences for code.\n"
        "- Avoid fluff. Avoid marketing language.\n"
        "- If you include code, keep it focused on the bullet being addressed.\n"
    )
)
,
            HumanMessage(
                content=(
                    f"Blog: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Topic: {topic}\n\n"
                    f"Section: {task.title}\n"
                    f"Section type: {task.section_type}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Bullets:{bullets_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [section_md]}

# %%
def reducer(state: State) -> dict:

    title = state["plan"].blog_title
    body = "\n\n".join(state["sections"]).strip()
    
    final_md = f"# {title}\n\n{body}\n"

    # Save to file
    filename = "".join(c if c.isalnum() or c in (" ", "_", "-") else "" for c in title)
    filename = filename.strip().lower().replace(" ", "_") + ".md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 5) Graph
# -----------------------------
g = StateGraph(State)
g.add_node("orchestrator", orchestrator)
g.add_node("worker", worker)
g.add_node("reducer", reducer)

g.add_edge(START, "orchestrator")
g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
out = app.invoke({"topic": "Write a blog on Self Attention", "sections": []})

# %%
print(out["final"])
# Out:
# # Demystifying Self-Attention: From Basics to Implementation
#
# ## Introduction to Self-Attention and Its Importance
#
# Traditional sequence modeling methods such as Recurrent Neural Networks (RNNs) and Convolutional Neural Networks (CNNs) have inherent limitations in handling long-range dependencies. RNNs process input sequentially, which makes capturing distant relationships challenging due to gradient vanishing/exploding issues and long training times. CNNs, limited by their fixed receptive fields, require deep stacking or large kernels to cover longer contexts, increasing model complexity and parameter counts.
#
# Self-attention addresses these challenges by directly relating each element in a sequence to every other, regardless of positional distance. This mechanism computes pairwise interactions within the input sequence, enabling the model to capture dependencies globally instead of just locally. The resulting representation reflects the contextual importance of all elements relative to each position.
#
# Common applications of self-attention include natural language processing (NLP), where the Transformer architecture relies heavily on it to replace recurrence and boost language understanding. Beyond NLP, vision models such as Vision Transformers (ViTs) apply self-attention to image patches, demonstrating improved global feature extraction. Other fields like speech processing and graph neural networks also leverage self-attention for richer relational modeling.
#
# A key advantage of self-attention is its ability to process sequence elements in parallel, unlike RNNs’ sequential nature. This parallelism significantly improves training efficiency by leveraging hardware accelerators like GPUs or TPUs more effectively, reducing wall-clock time while scaling to larger data.
#
# At a high level, self-attention layers operate by projecting inputs into query (Q), key (K), and value (V) vectors. The compatibility between Q and K (via dot product) determines attention scores, which are normalized typically with softmax. These scores weight the values V to produce context-aware outputs per element. This workflow can be summarized as:
#
# ```
# Input sequence -> Linear projections (Q, K, V)
# Q * K^T -> Attention scores -> Softmax normalization
# Softmax scores * V -> Output representations
# ```
#
# Overall, self-attention provides a flexible, scalable method to model complex dependencies over sequences, making it a fundamental component in modern deep learning architectures.
#
# ## Core Concepts and Mathematical Foundation of Self-Attention
#
# At the heart of self-attention are three key components: **query (Q)**, **key (K)**, and **value (V)** vectors. For an input sequence \(\mathbf{X} = [x_1, x_2, \ldots, x_n]\), each input element is projected linearly into these three vectors:
#
# \[
# Q = XW^Q, \quad K = XW^K, \quad V = XW^V
# \]
#
# where \(W^Q, W^K, W^V \in \mathbb{R}^{d_{\text{model}} \times d_k}\) are learned projection matrices, and \(d_k\) is the dimension of the query and key vectors.
#
# - **Queries (\(Q\))** represent the current position’s request for information.
# - **Keys (\(K\))** represent the indexed content in the sequence.
# - **Values (\(V\))** hold the actual data to be aggregated based on attention scores.
#
# ### Scaled Dot-Product Attention Formula
#
# The self-attention mechanism computes attention weights by measuring the compatibility between queries and keys. The scaled dot-product attention is defined as:
#
# \[
# \text{Attention}(Q, K, V) = \text{softmax}\left(\frac{Q K^\top}{\sqrt{d_k}}\right) V
# \]
#
# Breaking down the formula:
#
# - Compute the raw attention scores: \(Q K^\top\), an \(n \times n\) matrix of dot products between queries and keys.
# - Scale by \(\frac{1}{\sqrt{d_k}}\) to counteract growing dot product magnitudes as \(d_k\) increases.
# - Apply \(\text{softmax}\) row-wise to form a probability distribution over keys for each query.
# - Multiply the resulting weights by the value matrix \(V\), aggregating relevant information.
#
# This yields an output matrix of the same shape as the input: \(n \times d_k\).
#
# ### Minimal Working Example (MWE)
#
# Consider a sequence of 2 elements, each projected into queries, keys, and values of dimension \(2\):
#
# \[
# Q = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}, \quad
# K = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}, \quad
# V = \begin{bmatrix} 5 & 5 \\ 10 & 10 \end{bmatrix}
# \]
#
# Step 1: Compute scaled dot products:
#
# \[
# Q K^\top = \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}
# \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}^\top =
# \begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}
# \]
#
# Scale by \(\frac{1}{\sqrt{2}} \approx 0.707\):
#
# \[
# \frac{Q K^\top}{\sqrt{2}} = \begin{bmatrix} 0.707 & 0 \\ 0 & 0.707 \end{bmatrix}
# \]
#
# Step 2: Apply softmax row-wise:
#
# \[
# \text{softmax}(\cdot) = \begin{bmatrix}
# \frac{e^{0.707}}{e^{0.707} + e^{0}} & \frac{e^{0}}{e^{0.707} + e^{0}} \\
# \frac{e^{0}}{e^{0} + e^{0.707}} & \frac{e^{0.707}}{e^{0} + e^{0.707}}
# \end{bmatrix}
# =
# \begin{bmatrix} 0.668 & 0.332 \\ 0.332 & 0.668 \end{bmatrix}
# \]
#
# Step 3: Multiply by values \(V\):
#
# \[
# \text{Attention}(Q, K, V) =
# \begin{bmatrix} 0.668 & 0.332 \\ 0.332 & 0.668 \end{bmatrix}
# \begin{bmatrix} 5 & 5 \\ 10 & 10 \end{bmatrix} =
# \begin{bmatrix} 6.66 & 6.66 \\ 7.34 & 7.34 \end{bmatrix}
# \]
#
# This output blends the original values based on attention weights, mixing the two inputs in a data-driven way.
#
# ### Positional Encoding Necessity
#
# Self-attention treats the input sequence as a set; it is inherently **permutation-invariant** because all pairwise interactions are computed without explicit position awareness. Without additional information, self-attention cannot differentiate between sequences like:
#
# \[
# [x_1, x_2, x_3] \quad \text{and} \quad [x_3, x_1, x_2]
# \]
#
# To resolve this, **positional encodings** are added to input embeddings, injecting sequence order as deterministic or learnable signals before projecting queries, keys, and values. This enables the model to contextualize the relative or absolute positions of elements.
#
# ### Why Scale by \(\sqrt{d_k}\)?
#
# Scaling by \(\sqrt{d_k}\) improves **numerical stability** during softmax computation. Without scaling, dot products \(Q K^\top\) have variance proportional to the dimension \(d_k\), which can produce large values causing the softmax to saturate:
#
# - Saturated softmax results in near-one-hot distributions, leading to vanishing gradients and training instability.
# - Dividing by \(\sqrt{d_k}\) normalizes the variance, keeping logits in a suitable range for effective gradient flow.
#
# This simple adjustment is crucial for convergence and stable self-attention training when \(d_k\) is large (e.g., 64 or 128 dimensions).
#
# ---
#
# This mathematical grounding equips you with both the intuition and concrete steps to implement self-attention and understand its role within transformer architectures.
#
# ## Implementing a Basic Self-Attention Module in PyTorch
#
# To build a simple self-attention layer from scratch in PyTorch, we'll define a class with learnable linear projections for query, key, and value. These projections map input embeddings into their respective subspaces essential for computing attention.
#
# ```python
# import torch
# import torch.nn as nn
# import torch.nn.functional as F
#
# class SelfAttention(nn.Module):
#     def __init__(self, embed_dim, dropout=0.1):
#         super(SelfAttention, self).__init__()
#         # Linear layers for Q, K, V projections
#         self.query_proj = nn.Linear(embed_dim, embed_dim)
#         self.key_proj = nn.Linear(embed_dim, embed_dim)
#         self.value_proj = nn.Linear(embed_dim, embed_dim)
#
#         self.dropout = nn.Dropout(dropout)
#         self.scale = embed_dim ** 0.5  # Scaling factor for dot-product attention
#
#     def forward(self, x, mask=None):
#         # x: (batch_size, seq_len, embed_dim)
#         Q = self.query_proj(x)  # (batch_size, seq_len, embed_dim)
#         K = self.key_proj(x)    # (batch_size, seq_len, embed_dim)
#         V = self.value_proj(x)  # (batch_size, seq_len, embed_dim)
#
#         # Compute raw attention scores by batch matrix multiplication
#         scores = torch.bmm(Q, K.transpose(1, 2))  # (batch_size, seq_len, seq_len)
#         scores = scores / self.scale
#
#         # Apply mask if provided to avoid attending to padded tokens or future tokens
#         if mask is not None:
#             scores = scores.masked_fill(mask == 0, float('-inf'))
#
#         attn_weights = F.softmax(scores, dim=-1)  # normalized attention weights
#         attn_weights = self.dropout(attn_weights)
#
#         # Weighted sum of values
#         output = torch.bmm(attn_weights, V)  # (batch_size, seq_len, embed_dim)
#         return output, attn_weights
# ```
#
# ### Handling Dropout and Masks
#
# The dropout layer is applied after the softmax normalization on attention weights to regularize the model and prevent overfitting. The mask tensor should be of shape `(batch_size, seq_len, seq_len)` with 1s indicating valid attention positions and 0s where attention is blocked, for example:
#
# - A padding mask that prevents attending to padded tokens.
# - A causal mask that blocks attending to future tokens in autoregressive decoding.
#
# Example mask creation for causal masking can be:
#
# ```python
# def causal_mask(seq_len):
#     return torch.tril(torch.ones(seq_len, seq_len)).unsqueeze(0)  # (1, seq_len, seq_len)
# ```
#
# ### Testing with a Small Input Tensor
#
# Test the self-attention layer with a random input of shape `(2, 5, 16)` — batch size 2, sequence length 5, embedding 16:
#
# ```python
# sa = SelfAttention(embed_dim=16)
# x = torch.rand(2, 5, 16)
# mask = causal_mask(5)  # causal mask for sequence length 5
#
# output, attn = sa(x, mask=mask)
# print(f"Input shape: {x.shape}")               # (2, 5, 16)
# print(f"Attention scores shape: {attn.shape}") # (2, 5, 5)
# print(f"Output shape: {output.shape}")          # (2, 5, 16)
# ```
#
# ### Runtime and Memory Considerations
#
# - The core bottleneck is computing `scores` with shape `(batch_size, seq_len, seq_len)`. Its memory and compute cost scales quadratically (`O(seq_len^2)`) with the sequence length.
# - Large batch sizes further multiply memory requirements linearly.
# - For very long sequences (e.g., thousands of tokens), this quadratic cost makes vanilla self-attention expensive and often requires approximations like sparse attention or locality-sensitive hashing.
# - On smaller sequences (up to a few hundred tokens), this approach is efficient enough on GPUs.
# - When designing practical models, be sure to balance sequence length, batch size, and embedding dimension against available hardware constraints.
#
# This simple implementation illustrates the key operations of self-attention and can be extended to multi-head, masked, or causal variants used in modern architectures.
#
# ## Common Mistakes When Using Self-Attention and How to Avoid Them
#
# ### Incorrect Handling of Padding Tokens
#
# When processing variable-length sequences, padding tokens must be masked during self-attention to avoid contaminating attention weights. If padding positions are not masked, the softmax will assign attention to meaningless tokens, degrading model performance.
#
# **How to implement masks properly:**
#
# ```python
# # mask: (batch_size, seq_len) boolean tensor where True indicates valid tokens
# attention_scores = torch.matmul(Q, K.transpose(-2, -1))  # (batch_size, seq_len, seq_len)
# mask = mask.unsqueeze(1).expand(-1, seq_len, -1)         # expand to (batch_size, seq_len, seq_len)
#
# # Set scores at padding token positions to a large negative value before softmax
# attention_scores = attention_scores.masked_fill(~mask, float('-inf'))
# attention_weights = torch.softmax(attention_scores, dim=-1)
# ```
#
# This ensures padded positions do not contribute to attention, preserving correct weighting.
#
# ---
#
# ### Neglecting the Scaling Factor
#
# The original Transformer paper scales dot products by \(\frac{1}{\sqrt{d_k}}\) to prevent large values before softmax, which can cause gradients to explode or vanish.
#
# Without scaling:
#
# - Attention scores can be very large in magnitude.
# - Softmax saturates to near one-hot vectors, causing sparse gradients.
#
# ```python
# d_k = Q.size(-1)
# # Correct scaling
# attention_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(d_k)
# attention_weights = torch.softmax(attention_scores, dim=-1)
# ```
#
# **Effect without scaling**: unstable training and slower convergence due to poor gradient flow.
#
# ---
#
# ### Overlooking Positional Encoding
#
# Self-attention alone is permutation-invariant and does not encode sequence order. Without positional encoding, models cannot distinguish token positions.
#
# **Example comparison:**
#
# - Without positional encoding, output representations do not change if token order is shuffled.
# - Adding sinusoidal or learned positional embeddings restores order information:
#
# ```python
# x = token_embeddings + positional_embeddings
# ```
#
# **Why it matters:** positional encoding allows the model to learn sequence patterns and dependencies tied to token order.
#
# ---
#
# ### Confusing Batch and Sequence Dimensions
#
# Self-attention tensors typically have shape `(batch_size, seq_len, d_model)`. Mixing up these dimensions leads to subtle bugs and shape mismatches, especially during `matmul` or `transpose` operations.
#
# **Debugging tips:**
#
# - Print tensor shapes before matrix ops: use `print(tensor.shape)`
# - Use asserts: `assert tensor.dim() == 3`
# - Remember attention score shape: `(batch_size, seq_len, seq_len)`
#
# Example mistake:
#
# ```python
# # Incorrect: transposing batch and sequence dims
# attention_scores = torch.matmul(Q, K.transpose(-1, -2))  # wrong shape, should be K.transpose(-2, -1)
# ```
#
# Correct:
#
# ```python
# attention_scores = torch.matmul(Q, K.transpose(-2, -1))
# ```
#
# ---
#
# ### Ignoring Performance Impact of Large Sequences
#
# Self-attention has \(O(n^2)\) memory and compute complexity with sequence length \(n\). Large sequences cause slow training and high memory use.
#
# **Solutions:**
#
# - Use sparse attention masks limiting tokens each position attends to (local windows).
# - Employ approximate attention algorithms like Linformer, Reformer, or Performer that reduce complexity.
# - Apply sequence chunking and recurrence to trade off computation for efficiency.
#
# **Trade-off:** approximate methods reduce accuracy but enable scaling to longer sequences impractical with full self-attention.
#
# ---
#
# By addressing these common pitfalls, you can implement stable, efficient, and robust self-attention models ready for practical applications.
#
# ## Advanced Topics and Optimization Considerations
#
# ### Multi-Head Attention: Benefits and Efficient Implementation
#
# Multi-head attention splits the input embeddings into multiple smaller subspaces, allowing the model to jointly attend to information from different representation subspaces at different positions. This increases the model's capacity and allows finer-grained focus patterns.
#
# To implement multi-head attention efficiently:
# - **Split embeddings** of dimension \(d_{\text{model}}\) into \(h\) heads of size \(d_k = d_{\text{model}} / h\).
# - Compute scaled dot-product attention independently for each head in parallel.
# - Concatenate the resulting outputs and project back to \(d_{\text{model}}\).
#
# Using highly optimized matrix operations and batching on GPUs or TPUs makes this parallelism efficient. Frameworks like PyTorch and TensorFlow offer built-in multi-head attention layers. When implementing from scratch, use a single linear layer for Q, K, V projections followed by reshaping for parallel heads to reduce overhead.
#
# ---
#
# ### Memory and Compute Complexity
#
# Self-attention’s core bottleneck is the **quadratic scaling** in both memory and compute with respect to the sequence length \(n\), since attention computes an \(n \times n\) similarity matrix. This:
#
# - Limits feasibility for very long sequences (e.g., thousands of tokens).
# - Causes large memory allocation for intermediate tensors and gradients.
#
# **Approximate methods** reduce this complexity:
#
# - **Linformer:** Projects keys and values into a lower-dimensional space, approximating full attention complexity to linear \(O(n)\).
# - **Performer:** Uses random feature methods to approximate the softmax kernel enabling linear time attention via kernel decompositions.
#
# **Trade-offs**: Approximate methods reduce memory and runtime but may lose some expressiveness and accuracy. Choosing between full and approximate attention depends on the application’s tolerance for precision loss and hardware constraints.
#
# ---
#
# ### Security and Privacy Considerations
#
# When self-attention models process **sensitive data** (e.g., medical or financial texts), key considerations include:
#
# - **Data leakage through attention maps:** Attention weights reveal relationships between tokens and could expose confidential information if logged inappropriately.
# - **Model inversion attacks:** Attackers may extract training data from model outputs or intermediate activations.
#
# **Mitigations**:
# - Avoid logging raw attention weights or mask sensitive tokens before logging.
# - Use differential privacy techniques during training.
# - Secure model checkpoints and restrict access to intermediate tensors.
# - Use encrypted computation techniques if deploying on untrusted hardware.
#
# ---
#
# ### Logging Attention Weights and Gradient Norms
#
# Observability is crucial for debugging training and interpreting the model's behavior:
#
# - Log intermediate attention weight tensors post-softmax per training step or per batch to monitor focus patterns.
# - Track gradient norms of Q, K, V projection layers to detect exploding or vanishing gradients.
#
# Example in PyTorch for logging attention weights and gradient norms:
#
# ```python
# def forward(self, x):
#     Q = self.Wq(x)
#     # ... compute attention weights 'attn_weights' ...
#     self.attn_weights = attn_weights.detach().cpu().numpy()
#     return output
#
# def log_grad_norms(model):
#     for name, param in model.named_parameters():
#         if param.grad is not None:
#             grad_norm = param.grad.data.norm(2).item()
#             print(f"Grad norm for {name}: {grad_norm:.4f}")
# ```
#
# Logging periodically helps identify training instabilities or attention collapse.
#
# ---
#
# ### Edge Cases: Long Sequences and Batching Trade-offs
#
# **Extremely long sequences** (e.g., 10k+ tokens) pose challenges:
#
# - Quadratic memory often exceeds GPU limits.
# - Chunking sequences or using sliding windows can mitigate but reduce global context.
#
# **Batching trade-offs**:
#
# - Larger batches improve hardware utilization but increase memory pressure, worsening quadratic scaling.
# - Small batches ease memory use but lower throughput.
# - Mixed precision and gradient checkpointing can alleviate memory issues.
#
# Hardware differences matter:
#
# - GPUs with large VRAM and tensor cores accelerate full attention.
# - TPUs offer fast matrix multiplies but may require sequence truncation.
# - CPU-based inference may rely on approximate methods or pruning.
#
# ---
#
# ### Summary Checklist
#
# - Use multi-head attention to improve model capacity; implement with parallel batch matrix operations.
# - Assess quadratic complexity; apply approximate attention if sequence length is very long.
# - Protect sensitive data by careful logging and employing privacy-preserving training methods.
# - Instrument models by recording attention weights and gradient norms to aid debugging.
# - Plan for hardware and batch sizing trade-offs; consider precision and memory optimization techniques.
#
# This holistic view helps engineers build performant, scalable, secure self-attention models tailored to their specific constraints.
#
# ## Summary Checklist and Next Steps for Mastering Self-Attention
#
# Use this checklist to validate your self-attention implementation before moving forward:
#
# - **Verify core operations**
#   - Ensure query (Q), key (K), and value (V) projections are implemented as separate linear layers with correct input/output dimensions.
#   - Confirm scaled dot-product calculation:
#     ```python
#     scores = (Q @ K.transpose(-2, -1)) / math.sqrt(d_k)
#     ```
#     where `d_k` is the dimension of the keys.
#   - Validate softmax is applied over the correct axis (usually the key dimension).
#
# - **Confirm proper masking and positional encoding**
#   - Check that attention masks (e.g., padding or causal masks) are applied additively before the softmax:
#     ```python
#     scores = scores.masked_fill(mask == 0, float('-inf'))
#     ```
#   - Verify positional encodings (sinusoidal or learned) are added appropriately to the input embeddings before projecting Q, K, V.
#
# - **Test with edge case inputs**
#   - Run inputs with various sequence lengths, including minimal (length=1) and maximal sequences your model supports.
#   - Validate padding behavior by inputting batches with sequences padded to different lengths, confirming masks effectively block attention to padding tokens.
#
# - **Measure performance trade-offs**
#   - Benchmark runtime and memory usage on your target hardware (GPU/CPU) for different batch sizes and sequence lengths.
#   - Assess impact of using full versus sparse attention, if applicable, to balance speed and accuracy.
#
# - **Recommended next steps**
#   - Explore transformer variants like *Transformer-XL*, *Longformer*, or *Reformer* for handling longer sequences or efficiency improvements.
#   - Use visualization tools (e.g., `bertviz` or custom heatmaps) to interpret attention maps and debug model behavior.
#   - Leverage frameworks like HuggingFace Transformers, which provide optimized implementations and pre-trained models, accelerating experimentation and deployment.
#
# Following this checklist ensures foundational correctness and provides a roadmap for deepening your expertise in self-attention mechanisms.
#
# ## Conclusion and Future Outlook of Self-Attention Mechanisms
#
# Self-attention has fundamentally transformed sequence modeling by enabling models to capture long-range dependencies with parallelizable computations. This mechanism underpins large-scale pre-trained architectures like Transformers, powering advances in NLP, vision, and beyond through scalable contextual understanding.
#
# Current research is rapidly evolving with innovations such as sparse attention patterns that reduce computation by focusing on relevant tokens, efficient transformer variants optimizing memory and speed, and multimodal attention that fuses inputs across text, images, and audio. These directions address the scalability and applicability challenges of vanilla self-attention, expanding its reach into resource-constrained settings and cross-domain tasks.
#
# We encourage you to experiment by integrating self-attention layers into custom architectures, profiling their computational and memory performance under different configurations. Practical familiarity with trade-offs will deepen your intuition for design choices when adapting self-attention to specific problems.
#
# For further study, explore the original Transformer paper (Vaswani et al., 2017), the Longformer and Linformer papers for efficient attention, and open-source implementations available in libraries such as Hugging Face’s Transformers and PyTorch. These resources provide both theoretical background and hands-on tools.
#
# Lastly, contributing to open-source projects or community forums helps accelerate innovation and refinement of self-attention mechanisms. Sharing experiences and improvements drives the ecosystem forward and fosters collective progress in this dynamic area.
